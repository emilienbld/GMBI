# %% [markdown]
# A modifier</br>
#
# Dans cette verison, traitement des lignes avce la librairie (donc personne en N-1 G2GAI)</br>
# Et traitement des lignes annuler_occupation</br>
# Recherche des abandons pour les mettre vacants</br>
# Recherche avec 2022</br>
#
# Ce programme créait trois nouveaux fichiers :</br>
# 1 fichier a rendre à la DGFiP</br>
# 1 fichier avec les lignes de G2GAI qui n'ont pas été traitées ou pas trouvées de correspondances</br>
# 1 fichier avec les lignes de GMBI qui n'ont pas été traitées</br>

# %% [markdown]
# # Import des Librairies et Bibliothèques

# %%
import csv
import os
import time
import re
from thefuzz import fuzz
from thefuzz import process
from unidecode import unidecode
from datetime import datetime

# %% [markdown]
# ## Débur du timer

# %%
start = time.time()

# %% [markdown]
# # Déclaration des Chemins et Création des Fichiers

# %%
# IMPORTANT DE CHANGER LES CHEMINS !!!
# Chemins des fichiers CSV
chemin = 'C:/Users/internet/Documents/impots'  # Chemin où se trouve les fichiers GMBI et G2GAI
nouveau_dossier = 'Traitement Rendu'  # Dossier où les fichiers seront retournés ! pas besoin de créer le dossier

# TESTE SUR DES TRANCHES DE DÉPARTEMENT POUR LE DOMANIAL
# Noms des fichiers en entée
# nom_fichier_GMBI = '1_157000019_01_240226_100714_V2024 - Copie.csv'  # Nom du fichier GMBI
nom_fichier_GMBI = 'GMBI1-10.csv'  # Nom du fichier GMBI
# nom_fichier_G2GAI = 'DGFIP_2023_2024_ain - Copie.csv'  # Nom du fichier G2GAI
nom_fichier_G2GAI = 'G2GAI1-10.csv'  # Nom du fichier G2GAI
nom_fichier_abandon = 'Domanial partie.csv'  # Nom du fichier des logemsnts en abandons G2GAI
# Nom des fichiers en sortie
nom_nouveau_fichier = "temp 1-10 TROISIEME " + nom_fichier_GMBI  # Fichier qui sera complet dans le dossier "rendu" ! pas besoin de créer le fichier
nom_G2GAI_non_trouve = 'temp 1-10 TROISIEME G2GAI Reste.csv'  # Nom du fichier où les lignes de G2GAI n'ont pas été traité à la fin ! pas besoin de créer le fichier
nom_GMBI_non_trouve = 'temp 1-10 TROISIEME GMBI Reste.csv'  # Nom du fichier où les lignes de GMBI n'ont pas été traité à la fin ! pas besoin de créer le fichier
nom_abandon_non_trouve = 'temp 1-10 TROISIEME Abandon Reste.csv'

# Créer les chemins complets
dossier_rendu = os.path.join(chemin, nouveau_dossier)
fichier_GMBI = os.path.join(chemin, nom_fichier_GMBI)
fichier_G2GAI = os.path.join(chemin, nom_fichier_G2GAI)
fichier_abandon = os.path.join(chemin, nom_fichier_abandon)
nouveau_fichier = os.path.join(dossier_rendu, nom_nouveau_fichier)
G2GAI_non_trouve = os.path.join(dossier_rendu, nom_G2GAI_non_trouve)
GMBI_non_trouve = os.path.join(dossier_rendu, nom_GMBI_non_trouve)

# Vérifier si le dossier rendu existe, sinon le créer
if not os.path.exists(dossier_rendu):
    os.makedirs(dossier_rendu)

# Fonction pour ouvrir les fichier GMBI et G2GAI et écrire les premières lignes dans les fchiers correspondants
def charger_ecrire_fichier(input_file, output_file, non_trouve_file):
    # Ouvrir le fichier d'entrée en mode lecture
    with open(input_file, 'r', newline='') as fichier_entree:
        lecteur_fichier_entree = csv.reader(fichier_entree, delimiter=';')
        premiere_ligne_fichier_entree = next(lecteur_fichier_entree)  # Lire la première ligne du fichier d'entrée

        # Ouvrir le fichier de sortie en mode écriture
        with open(output_file, 'w', newline='') as fichier_sortie:
            writer = csv.writer(fichier_sortie, delimiter=';')
            writer.writerow(premiere_ligne_fichier_entree)  # Écrire la première ligne dans le fichier de sortie

        # Ouvrir le fichier "non_trouve" en mode écriture
        with open(non_trouve_file, 'w', newline='') as non_trouve:
            writer = csv.writer(non_trouve, delimiter=';')
            writer.writerow(premiere_ligne_fichier_entree)  # Écrire la première ligne dans le fichier "non_trouve"

        donnees_fichier_entree = list(lecteur_fichier_entree)  # Lire toutes les données du fichier d'entrée et les stocker dans une liste
    
    # Retourner la première ligne et les données du fichier d'entrée
    return premiere_ligne_fichier_entree, donnees_fichier_entree

# Charger les données du fichier GMBI
premiere_ligne_GMBI, donnees_fichierGMBI = charger_ecrire_fichier(fichier_GMBI, nouveau_fichier, GMBI_non_trouve)
# Charger les données du fichier G2GAI
premiere_ligne_G2GAI, donnees_fichierG2GAI = charger_ecrire_fichier(fichier_G2GAI, G2GAI_non_trouve, G2GAI_non_trouve)
# Charger les données du fichier des logements en abandons
premiere_ligne_abandon, donnees_fichierAbandon = charger_ecrire_fichier(fichier_abandon, nom_abandon_non_trouve, nom_abandon_non_trouve)

# %% [markdown]
# # Variables des dates Arrivée / Départ

# %%
date_depart = "31/12/2023"
date_arrivee = "01/01/2024"

# %% [markdown]
# # Initialisation des Listes traitées

# %%
# Initialiser un ensemble pour stocker les valeurs déjà traitées de GMBI
valeurs_gmbi_traitees = set()
# Initialiser un ensemble pour stocker les valeurs déjà traitées de G2GAI
valeurs_g2gai_traitees = set()
# Initialiser un ensemble pour stocker les valeurs déjà traitées de G2GAI de 2022
valeurs_g2gai_traitees2022 = set()
# Initialiser un ensemble pour stocker les valeurs déjà traitées de G2GAI de 2023
valeurs_g2gai_traitees2023 = set()
# Initialiser un ensemble pour stocker les valeurs déjà traitées des abandons
valeurs_abandon_traitees = set()

# %% [markdown]
# # Fonction pour la date de naissance du gendarme

# %%
# Fonction pour trouver le gendarme en Spi 1 ou 2 pour lui mettre sa date de naissance
def mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI, date_naissance_spi_1=38, date_naissance_spi_2=52):
    if nom_precedent in nouvelle_ligne and premier_prenom_precedent_G2GAI in nouvelle_ligne:
        if nom_precedent == spi1_nom_GMBI and premier_prenom_precedent_G2GAI == spi1_prenom_GMBI:
            nouvelle_ligne[date_naissance_spi_1] = date_naissance_precedente
        else:
            nouvelle_ligne[date_naissance_spi_2] = date_naissance_precedente

# %% [markdown]
# # Fonction pour renseigner l'idGroupLoc

# %%
# Fonction pour récupérer l'idGrouLoc et l'assigner à la nouvelle ligne (A utiliser quand il n'est pas déjà present)
def recuperer_idGroupLoc_et_assigner(donnees_fichierGMBI, departement_local_GMBI, valeurs_gmbi_traitees, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, nouvelle_ligne):
    for ligne_GMBI in donnees_fichierGMBI:
        # Vérifier les conditions pour récupérer idGroupLoc
        if (departement_local_GMBI == ligne_GMBI[4] and
                ligne_GMBI[2] in valeurs_gmbi_traitees and
                "partie" in ligne_GMBI[18].lower() and
                # nom_precedent_G2GAI in ligne_GMBI and
                (fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[49]) == 100) and
                premier_prenom_precedent_G2GAI in ligne_GMBI):

            nouvelle_ligne[3] = ligne_GMBI[2]  # Écrire l'idGroupLoc dans nouvelle_ligne
            break  # Sortir de la boucle une fois que la première correspondance est trouvée

# %% [markdown]
# # Fonction pour déterminer le type d'occupation / numéro du logment

# %%
# Fonction pour mettre le type d'occupation et le numéro de logement dans la case observation
def determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI):
    if nouvelle_ligne[35].strip() != '':
        nouvelle_ligne[32] = "4"
        nouvelle_ligne[33] = "1"
        nouvelle_ligne[42:45] = [""] * 3
    else:
        nouvelle_ligne[32] = "3"
        nouvelle_ligne[33] = ""
    nouvelle_ligne[64] = numero_logement_G2GAI

# %% [markdown]
# # Fonction pour dupliquer la ligne

# %%
# Fonction pour copier la ligne et mettre "X" dans la première cellule
def creer_nouvelle_ligne(ligne_GMBI):
    nouvelle_ligne = ligne_GMBI[:]  # Copie de la ligne correspondante
    nouvelle_ligne[0] = "X"  # Mettre "X" dans la colonne "declarer"
    return nouvelle_ligne

# %% [markdown]
# # Fonction pour écrire une ligne

# %%
# Fonction pour écrire dans un fichier CSV
def ecrire_ligne_csv(fichier, ligne):
    with open(fichier, 'a', newline='') as fichier_csv:
        writer = csv.writer(fichier_csv, delimiter=';')
        writer.writerow(ligne)

# %% [markdown]
# # Fonction pour récupérer les données sur le logement de la ligne G2GAI

# %%
# Fonction pour extraire les information du logement de G2GAI
def informations_logement_G2GAI(ligne_G2GAI):
    departement_logement_G2GAI = ligne_G2GAI[2]  # Colonne C, département du logement
    departement_logement_G2GAI = convertir_code_departement_corse(departement_logement_G2GAI)  # Appel de la focntion pour vérifier si le département est de la Corse
    numero_logement = ligne_G2GAI[12]  # Colonne M, numéro du logement
    return departement_logement_G2GAI, numero_logement

# %% [markdown]
# # Fonction pour récupérer les données de l'occupant précédent de la ligne G2GAI

# %%
# Fonction pour extraire les information de l'occupant en N-1 de G2GAI
def informations_occupant_precedent(ligne_G2GAI):
    nigend_precedent = ligne_G2GAI[19]  # Colonne T, NIGEND N-1
    nom_precedent = ligne_G2GAI[20]  # Colonne U, NOM N-1
    nom_precedent = convertir_caracteres_speciaux(nom_precedent)
    prenom_precedent = ligne_G2GAI[21]  # Colonne V, PRÉNOM N-1
    premier_prenom_precedent = prenom_precedent.split(' ')[0]  # Garder seulement le premier prénom
    date_naissance_precedente = ligne_G2GAI[22]  # Colonne W, DATE DE NAISSANCE
    return nigend_precedent, nom_precedent, prenom_precedent, premier_prenom_precedent, date_naissance_precedente

# %% [markdown]
# # Fonction pour récupérer les données de l'occupant courant de la ligne G2GAI

# %%
# Fonction pour extraire les information de l'occupant en N de G2GAI
def informations_occupant_courant(ligne_G2GAI):
    nigend_courant = ligne_G2GAI[26]  # Colonne AA, NIGEND N
    nom_courant = ligne_G2GAI[27]  # Colonne AB, NOM N
    nom_courant = convertir_caracteres_speciaux(nom_courant)
    prenom_courant = ligne_G2GAI[28]  # Colonne AC, PRÉNOM N
    premier_prenom_courant_G2GAI = prenom_courant.split(' ')[0]
    date_naissance_courante = ligne_G2GAI[29]  # Colonne AD, DATE DE NAISSANCE
    return nigend_courant, nom_courant, prenom_courant,premier_prenom_courant_G2GAI, date_naissance_courante

# %% [markdown]
# # Fonction pour récupérer les données du logement de la ligne GMBI

# %%
# Fonction pour extraire les information du logement de GMBI
def informations_logement_GMBI(ligne_GMBI):
    departement_local_GMBI = ligne_GMBI[4]  # Colonne E, CODE DÉPARTEMENT
    numero_fiscal_GMBI = ligne_GMBI[2]  # Colonne C, NUMÉRO FISCAL DU LOCAL
    spi1_nom_GMBI = ligne_GMBI[35]  # Colonne AJ, NOM DU SPI 1
    spi1_prenom_GMBI = ligne_GMBI[37]  # Colonne AL, PRÉNOM DU SPI 1
    return departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI

# %% [markdown]
# # Fonction qui convertit les départements (Corse)

# %%
# Fonction qui vérifie si le département est de la Corse pour le convertir comme écrit dans le fichier GMBI
def convertir_code_departement_corse(departement):
    if departement in ['201', '202']:
        if departement == '201':
            return '2A'
        elif departement == '202':
            return '2B'
    return departement

# %% [markdown]
# # Fonction pour vérifier les dates d'arrivées avec celles initialisées cette année

# %%
# Fonction pour vérifier si la date d'arrivée est présente et inférieur à la date de départ
def verifier_date_arrivee(ligne, date_arrivee):
    # Vérifier si la cellule en indice 45 est présente et si la date est inférieure à date_arrivee
    if ligne[45] and datetime.strptime(ligne[45], "%d/%m/%Y") < datetime.strptime(date_arrivee, "%d/%m/%Y"):
        return True
    return False

# %% [markdown]
# # Fonction pour gérer le problème de la date ou de la vacance

# %%
# Écriture des lignes si le format de la date d'arrviée n'est pas bonne
def ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees):
    nouvelle_ligne = ligne_GMBI[:]
    nouvelle_ligne[1] = "Cause date ou occ"
    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
    nouvelle_ligne[0] = "Cause date ou occ Ajout"
    nouvelle_ligne[1] = ""
    nouvelle_ligne[35] = nom_courant_G2GAI
    nouvelle_ligne[37] = premier_prenom_courant_G2GAI
    nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissance du nouveau gendarme
    determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
    nouvelle_ligne[45] = date_arrivee
    nouvelle_ligne[46:61] = [""] * 15
    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
    valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traitées
    valeurs_g2gai_traitees.add(numero_logement_G2GAI)

# %% [markdown]
# # Fonction pour vérifier la vacance et l'occupation

# %%
# Écriture des lignes si la ligne est déclarée comme vacante et occupée ou vacante deux fois
def verifier_vacance_occupation(ligne):
    if (ligne[33].strip() != '' and 
        ((ligne[44].strip() != '' and ligne[49].strip() == '' and ligne[58].strip() == '') or 
        (ligne[44].strip() == '' and ligne[35].strip() != '' and ligne[58].strip() == ''))):
        return True
    return False

# %% [markdown]
# # Fonction pour convertir les caractères

# %%
# Fonction pour convertir les caractères spéciaux en nornaux (EX : Ÿ -> Y)
def convertir_caracteres_speciaux(chaine):
    return unidecode(chaine)

# %% [markdown]
# # Fonction pour récupérer les données pour la correspondance avec adresse

# %%
# Fonction pour initialiser les variables nécessaires pour traiter les lignes avec l'adresse
def initialiser_variables_adresse(ligne_G2GAI):
    departement_logement_G2GAI, numero_logement_G2GAI = informations_logement_G2GAI(ligne_G2GAI)
    nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI,premier_prenom_courant_G2GAI, date_naissance_courante = informations_occupant_courant(ligne_G2GAI)

    adresse_G2GAI = ligne_G2GAI[8]
    adresse_G2GAI_caracteres = re.sub(r'\d', '', adresse_G2GAI)
    adresse_G2GAI_chiffres = re.sub(r'\D', '', adresse_G2GAI)

    etage_G2GAI = ligne_G2GAI[11]

    surface_G2GAI = ligne_G2GAI[13]
    ecart_maximal_surface = 5
    nbr_pieces_G2GAI = ligne_G2GAI[14]
    ecart_maximal_piece = 2

    return departement_logement_G2GAI, numero_logement_G2GAI, nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, adresse_G2GAI, adresse_G2GAI_caracteres, adresse_G2GAI_chiffres, etage_G2GAI, surface_G2GAI, ecart_maximal_surface, nbr_pieces_G2GAI, ecart_maximal_piece

# %% [markdown]
# # Fonction qui traite les locaux associés au logement des dates du 1er janvier de cette année

# %%
# Fonction pour les locaux associés au logement des dates 01/01/2024 de GMBI
def date_gmbi(ligne_GMBI, nouveau_fichier, numero_logement_G2GAI, date_naissance_courante, date_arrivee, valeurs_gmbi_traitees):
    print("local")
    # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
    nouvelle_ligne = ligne_GMBI[:]  
    nouvelle_ligne[0] = "2"  
    # Déterminer le type d'occupation
    determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
    # Mettre la date de naissance en fonction du Spi du gendare
    if premier_prenom_courant_G2GAI == ligne_GMBI[37]:
        nouvelle_ligne[38] = date_naissance_courante
    else:
        nouvelle_ligne[52] = date_naissance_courante
    nouvelle_ligne[45] = date_arrivee  
    # Mettre la date d'arrivée dans la colonne correspondante si nécessaire
    if ligne_GMBI[49].strip() != '':
        ligne_GMBI[59] = date_arrivee
    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
    valeurs_gmbi_traitees.add(ligne_GMBI[2])

# %% [markdown]
# # Fonction pour traiter la correspndance par adresse

# %%
def traiter_correspondance(ligne_GMBI, date_arrivee, date_depart, numero_logement_G2GAI, adresse_G2GAI_caracteres, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, nouveau_fichier, valeurs_gmbi_traitees, valeurs_g2gai_traitees, numero_fiscal_GMBI, departement_local_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI):

# Traitement de la correspondance
    departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI = informations_logement_GMBI(ligne_GMBI)

    if ligne_GMBI[33:44] != [""] * 11 :

        if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

            # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
            nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
            nouvelle_ligne[0] = "test 4 Adresse Supprime PP"  # A ENLEVER
            nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1
            # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
            if nouvelle_ligne[49].strip() != '':
                nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
            nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER
            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

            nouvelle_ligne[0] = "test 5 Adresse Ajout PP"  # A ENLEVER
            nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
            # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
            nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
            nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
            nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER
            nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

            # Vider le Spi_2
            nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2
            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

            valeurs_gmbi_traitees.add(numero_fiscal_GMBI)
            valeurs_g2gai_traitees.add(numero_logement_G2GAI)

        else:
            ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)

    else:
        nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
        nouvelle_ligne[0] = "test 6 Adresse Ajout PP"  # A ENLEVER
        nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
        # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
        nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
        nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

        # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
        determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
        nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER
        nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

        # Vider le Spi_2
        nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2
        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

        valeurs_gmbi_traitees.add(numero_fiscal_GMBI)
        valeurs_g2gai_traitees.add(numero_logement_G2GAI)


    # Local associer au logement
    for ligne_GMBI in donnees_fichierGMBI:
        
        # S'il ne s'agit pas d'une partie principale 
        if "partie" not in ligne_GMBI[18].lower() and ligne_GMBI[3].strip() != '':

            # Recherhcer les "dépendances" affectées à ce local
            if (departement_local_GMBI == ligne_GMBI[4] and
                ligne_GMBI[2] not in valeurs_gmbi_traitees and
                numero_fiscal_GMBI == ligne_GMBI[3]):

                if ligne_GMBI[33:44] != [""] * 11 :

                    if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                        # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                        nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER

                        nouvelle_ligne[0] = "test 7 Adresse Supprime L"  # A ENLEVER
                        nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1
                        # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                        if nouvelle_ligne[49].strip() != '':
                            nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                        determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                        nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER

                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                        nouvelle_ligne[0] = "test 8 Adresse Ajout L"  # A ENLEVER
                        nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                        # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                        nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                        nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                        # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                        determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                        nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER
                        nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                        # Vider le Spi_2
                        nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2
                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                        valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité

                    else:
                        ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)

                else:
                    nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                    nouvelle_ligne[0] = "test 9 Adresse Ajout L"  # A ENLEVER
                    nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                    # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                    nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                    nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                    # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                    determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                    nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER
                    nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                    # Vider le Spi_2
                    nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2
                    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                    valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité


        if spi1_nom_GMBI and spi1_prenom_GMBI:
            if (departement_local_GMBI == ligne_GMBI[4] and
                ligne_GMBI[2] not in valeurs_gmbi_traitees and
                spi1_nom_GMBI in ligne_GMBI and 
                spi1_prenom_GMBI in ligne_GMBI):

                if ligne_GMBI[33:44] != [""] * 11 :

                    if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):
                        # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                        nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER

                        nouvelle_ligne[0] = "test 10 Local avec adresse Suprimme"  # A ENLEVER
                        nouvelle_ligne[3] = numero_fiscal_GMBI
                        nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1
                        # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                        if nouvelle_ligne[49].strip() != '':
                            nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                        determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                        nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER

                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                        nouvelle_ligne[0] = "test 11 Local avec adresse Ajout"  # A ENLEVER
                        nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                        # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                        nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                        nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                        # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                        determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                        nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER
                        nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                        # Vider le Spi_2
                        nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2
                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                        valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité

                    else:
                        ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)

                else:
                    nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                    nouvelle_ligne[0] = "test 12 Local avec adresse Ajout"  # A ENLEVER
                    nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                    # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                    nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                    nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                    # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                    determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                    nouvelle_ligne[64] = numero_logement_G2GAI  # A ENLEVER
                    nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                    # Vider le Spi_2
                    nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2
                    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                    valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité

# %% [markdown]
# # Recherche des logements avec la date du 1er janvier de cette année

# %%
# Recherche des 01/01/2024 de GMBI
for ligne_GMBI in donnees_fichierGMBI:

    if ligne_GMBI[45] == '01/01/2024' and "partie" in ligne_GMBI[18].lower() and ligne_GMBI[2] not in valeurs_gmbi_traitees:
        print("Touvé")
        departement_local_GMBI = ligne_GMBI[4]
        numero_fiscal_GMBI = ligne_GMBI[2]
        nom_GMBI = ligne_GMBI[35]
        prenom_GMBI = ligne_GMBI[37]
        adresse_GMBI = ligne_GMBI[8]

        for ligne_G2GAI in donnees_fichierG2GAI:

            if ligne_G2GAI[27].strip() != '':
                nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante = informations_occupant_courant(ligne_G2GAI)
                departement_logement_G2GAI, numero_logement_G2GAI = informations_logement_G2GAI(ligne_G2GAI)

                if (departement_local_GMBI == departement_logement_G2GAI and
                    numero_logement_G2GAI not in valeurs_g2gai_traitees and
                    (((fuzz.partial_token_sort_ratio(nom_courant_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_courant_G2GAI, ligne_GMBI[35]) == 100) and
                    premier_prenom_courant_G2GAI == ligne_GMBI[37]) or
                    ((fuzz.partial_token_sort_ratio(nom_courant_G2GAI, ligne_GMBI[49]) == 100 or fuzz.partial_token_sort_ratio(nom_courant_G2GAI, ligne_GMBI[49]) == 100) and
                    premier_prenom_courant_G2GAI == ligne_GMBI[51]))):
                    print("correspondance")
                                        
                    date_naissance_trouvee = date_naissance_courante

                    # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                    nouvelle_ligne = ligne_GMBI[:]  # Copie de la ligne correspondante
                    nouvelle_ligne[0] = "Recherche 01/01/2024"  # Mettre "X" dans la colonne "declarer"
                    determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                    if premier_prenom_courant_G2GAI == prenom_GMBI:
                        nouvelle_ligne[38] = date_naissance_courante
                    else:
                        nouvelle_ligne[52] = date_naissance_courante

                    # Écrire la ligne modifiée dans le nouveau fichier 
                    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                    valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité
                    valeurs_g2gai_traitees.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées

                    if numero_fiscal_GMBI in valeurs_gmbi_traitees:

                        for ligne_GMBI in donnees_fichierGMBI:

                            if (ligne_GMBI[2] not in valeurs_gmbi_traitees and
                                "partie" not in ligne_GMBI[18].lower() and
                                ligne_GMBI[3].strip() != ''):

                                if ligne_GMBI[3] == numero_fiscal_GMBI and ligne_GMBI[2] not in valeurs_gmbi_traitees:

                                    date_gmbi(ligne_GMBI, nouveau_fichier, numero_logement_G2GAI, date_naissance_courante, date_arrivee, valeurs_gmbi_traitees)

                                if (ligne_GMBI[2] not in valeurs_gmbi_traitees and
                                    ((ligne_GMBI[35] == nom_GMBI and ligne_GMBI[37] == prenom_GMBI) or
                                    (ligne_GMBI[49] == nom_GMBI and ligne_GMBI[51] == prenom_GMBI)) and
                                    ligne_GMBI[4] == departement_local_GMBI and
                                    ligne_GMBI[8] == adresse_GMBI):

                                    date_gmbi(ligne_GMBI, nouveau_fichier, numero_logement_G2GAI, date_naissance_courante, date_arrivee, valeurs_gmbi_traitees)
# Recherche des 01/01/2024 de GMBI

# %% [markdown]
# # Recherche des gendarmes de 2022 de G2GAI dans GMBI

# %%
# 2022
# Parcourir les lignes du fichier G2GAI
for ligne_G2GAI in donnees_fichierG2GAI:

    # Si le logement est Domaniale
    if ligne_G2GAI[16] == "D" and ligne_G2GAI[12] not in valeurs_g2gai_traitees:

        # Appel des focntion pour initialisation des variable de G2GAI
        departement_logement_G2GAI, numero_logement_G2GAI = informations_logement_G2GAI(ligne_G2GAI)
        nigend_precedent, nom_precedent_G2GAI, prenom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente = informations_occupant_precedent(ligne_G2GAI)
        nigend_2022 = ligne_G2GAI[33]
        nom_2022_G2GAI = ligne_G2GAI[34]
        prenom_2022_G2GAI = ligne_G2GAI[35]
        premier_prenom_2022_G2GAI = prenom_2022_G2GAI.split(' ')[0]
        date_naissance_2022 = ligne_G2GAI[36]
        nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante = informations_occupant_courant(ligne_G2GAI)

        # S'il y a quelqu'un en 2022 dans G2GAI
        if nigend_2022.strip() != '':

            # Si les nigneds sont égaux en 2022 et 2023 dans G2GAI
            if nigend_2022 != nigend_precedent:

                # Parcourir les lignes du fichier GMBI
                for ligne_GMBI in donnees_fichierGMBI:

                    # S'il s'agit d'une partie principale
                    if ("partie" in ligne_GMBI[18].lower() and
                        ligne_GMBI[2] not in valeurs_gmbi_traitees and 
                        ligne_GMBI[3]==""):

                        # Appel de la  focntion pour initialisation des variable de GMBI
                        departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI = informations_logement_GMBI(ligne_GMBI)

                        # Chercher une correspondance entre la ligne de G2GAI avec celle de GMBI
                        if (departement_logement_G2GAI == departement_local_GMBI and
                            (fuzz.partial_token_sort_ratio(nom_2022_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_2022_G2GAI, ligne_GMBI[49]) == 100) and
                            premier_prenom_2022_G2GAI in ligne_GMBI):

                            if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                                # Créer une nouvelle ligne avec les modifications nécessaires
                                # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                                nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                                nouvelle_ligne[0] = "2022Parti PP"  # A ENLEVER
                                nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1

                                # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                                mettre_date_naissance_gendarme(nouvelle_ligne, nom_2022_G2GAI, premier_prenom_2022_G2GAI, date_naissance_2022, spi1_nom_GMBI, spi1_prenom_GMBI)

                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                                if nouvelle_ligne[49].strip() != '':
                                    nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                                # Écrire la ligne modifiée dans le nouveau fichier
                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                                # Renseigner le nouvel occupant
                                nouvelle_ligne[0] = "2022Decla PP"  # A ENLEVER
                                nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                                nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                                nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                # Mettre la date d'arrivée
                                nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                                # Vider l'Id Spi_1
                                # nouvelle_ligne[34] = ""  # Suppression de l'Id (dans la version 2023-2024 iln'y en a pas)

                                # Vider le Spi_2
                                nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2

                                # Écrire la ligne modifiée dans le nouveau fichier
                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité
                                valeurs_g2gai_traitees.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées
                                valeurs_g2gai_traitees2022.add(numero_logement_G2GAI)
                            
                            else:
                                ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)
                                valeurs_g2gai_traitees2022.add(numero_logement_G2GAI)
                                
                            for ligne_GMBI in donnees_fichierGMBI:
                                
                                # S'il ne s'agit pas d'une partie principale 
                                if "partie" not in ligne_GMBI[18].lower() and ligne_GMBI[3].strip() != '':

                                    # Recherhcer les "dépendances" affectées à ce local
                                    if (departement_local_GMBI == ligne_GMBI[4] and
                                        ligne_GMBI[2] not in valeurs_gmbi_traitees and
                                        numero_fiscal_GMBI == ligne_GMBI[3]):

                                        if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                                            # Créer une nouvelle ligne avec les modifications nécessaires
                                            # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                                            nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                                            nouvelle_ligne[0] = "2022Parti L"  # A ENLEVER
                                            nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1

                                            # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                                            mettre_date_naissance_gendarme(nouvelle_ligne, nom_2022_G2GAI, premier_prenom_2022_G2GAI, date_naissance_2022, spi1_nom_GMBI, spi1_prenom_GMBI)

                                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                            # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                                            if nouvelle_ligne[49].strip() != '':
                                                nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                                            # Écrire la ligne modifiée dans le nouveau fichier
                                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                                            nouvelle_ligne[0] = "2022Decla PP"  # A ENLEVER
                                            nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                                            nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                                            nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                            # Mettre la date d'arrivée
                                            nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                                            # Vider l'Id Spi_1
                                            # nouvelle_ligne[34] = ""  # Suppression de l'Id (dans la version 2023-2024 iln'y en a pas)

                                            # Vider le Spi_2
                                            nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2

                                            # Écrire la ligne modifiée dans le nouveau fichier
                                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                            valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité
                                        
                                        else:
                                            ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)
                                            valeurs_g2gai_traitees2022.add(numero_logement_G2GAI)

# %% [markdown]
# # Recherche locaux associes au logements de 2022

# %%
# Recherche des locaux assiciés aux logements traités 2022
for ligne_G2GAI in donnees_fichierG2GAI:

    # Si le logement est Domaniale
    if ligne_G2GAI[16] == "D" and ligne_G2GAI[12] in valeurs_g2gai_traitees2022:
        
        # Appel des focntion pour initialisation des variable de G2GAI
        departement_logement_G2GAI, numero_logement_G2GAI = informations_logement_G2GAI(ligne_G2GAI)
        nigend_precedent, nom_precedent_G2GAI, prenom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente = informations_occupant_precedent(ligne_G2GAI)
        nigend_2022 = ligne_G2GAI[33]
        nom_2022_G2GAI = ligne_G2GAI[34]
        prenom_2022_G2GAI = ligne_G2GAI[35]
        premier_prenom_2022_G2GAI = prenom_2022_G2GAI.split(' ')[0]
        date_naissance_2022 = ligne_G2GAI[36]
        nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante = informations_occupant_courant(ligne_G2GAI)

        # Parcourir les lignes du fichier GMBI
        for ligne_GMBI in donnees_fichierGMBI:

            # S'il s'agit d'une partie principale 
            if ("partie" not in ligne_GMBI[18].lower() and
                ligne_GMBI[3].strip() == '' and
                ligne_GMBI[2] not in valeurs_gmbi_traitees):

                # Appel de la  focntion pour initialisation des variable de GMBI
                departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI = informations_logement_GMBI(ligne_GMBI)

                # Chercher une correspondance entre la ligne de G2GAI avec celle de GMBI
                if (departement_logement_G2GAI == departement_local_GMBI and 
                    # nom_2022_G2GAI in ligne_GMBI and
                    (fuzz.partial_token_sort_ratio(nom_2022_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_2022_G2GAI, ligne_GMBI[49]) == 100) and
                    premier_prenom_2022_G2GAI in ligne_GMBI):

                    if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                        # Si les nigneds sont égaux en N-1 et N dans G2GAI
                        if nigend_2022 == nigend_courant:

                            # Créer une nouvelle ligne avec les modifications
                            # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                            nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                            nouvelle_ligne[0] = "2022Decla L"  # A ENLEVER

                            # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                            mettre_date_naissance_gendarme(nouvelle_ligne, nom_2022_G2GAI, premier_prenom_2022_G2GAI, date_naissance_2022, spi1_nom_GMBI, spi1_prenom_GMBI)

                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                            recuperer_idGroupLoc_et_assigner(donnees_fichierGMBI, departement_local_GMBI, valeurs_gmbi_traitees, nom_2022_G2GAI, premier_prenom_2022_G2GAI, nouvelle_ligne)

                            # Écrire la ligne modifiée dans le nouveau fichier 
                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                            valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité

                        else:
                            # Créer une nouvelle ligne avec les modifications nécessaires
                            # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                            nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                            nouvelle_ligne[0] = "2022Parti L"  # A ENLEVER
                            nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1

                            # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                            mettre_date_naissance_gendarme(nouvelle_ligne, nom_2022_G2GAI, premier_prenom_2022_G2GAI, date_naissance_2022, spi1_nom_GMBI, spi1_prenom_GMBI)

                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                            # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                            if nouvelle_ligne[49].strip() != '':
                                nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                            recuperer_idGroupLoc_et_assigner(donnees_fichierGMBI, departement_local_GMBI, valeurs_gmbi_traitees, nom_2022_G2GAI, premier_prenom_2022_G2GAI, nouvelle_ligne)

                            # Écrire la ligne modifiée dans le nouveau fichier
                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                            # Renseigner le nouvel occupant
                            nouvelle_ligne[0] = "2022Decla L"  # A ENLEVER
                            nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                            # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                            nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                            nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                            # CHANGER L'ID SPI
                            nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                            # Vider l'Id Spi_1
                            # nouvelle_ligne[34] = ""  # Suppression de l'Id (dans la version 2023-2024 iln'y en a pas)

                            # Vider le Spi_2
                            nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2

                            # Écrire la ligne modifiée dans le nouveau fichier
                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                            valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité

                    else:
                        nouvelle_ligne = ligne_GMBI[:]
                        nouvelle_ligne[1] = "2022Parti Erreur L"
                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                        nouvelle_ligne[0] = "2022Decla Erreur L"
                        nouvelle_ligne[1] = ""
                        nouvelle_ligne[35] = nom_courant_G2GAI
                        nouvelle_ligne[37] = premier_prenom_courant_G2GAI
                        nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme
                        determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                        recuperer_idGroupLoc_et_assigner(donnees_fichierGMBI, departement_local_GMBI, valeurs_gmbi_traitees, nom_2022_G2GAI, premier_prenom_2022_G2GAI, nouvelle_ligne)
                        nouvelle_ligne[45] = date_arrivee
                        nouvelle_ligne[46:61] = [""] * 15
                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                        valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité
                        # valeurs_g2gai_traitees.add(numero_logement_G2GAI)
                        # valeurs_g2gai_traitees2022.add(numero_logement_G2GAI)
# 2022

# %% [markdown]
# # Recherche des gendarmes de l'année précédente de G2GAI dans GMBI

# %%
# 2023
# Parcourir les lignes du fichier G2GAI
for ligne_G2GAI in donnees_fichierG2GAI:

    # Si le logement est Domaniale
    if ligne_G2GAI[16] == "D" and ligne_G2GAI[12] not in valeurs_g2gai_traitees:

        # Appel des focntion pour initialisation des variable de G2GAI
        departement_logement_G2GAI, numero_logement_G2GAI = informations_logement_G2GAI(ligne_G2GAI)
        nigend_precedent, nom_precedent_G2GAI, prenom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente = informations_occupant_precedent(ligne_G2GAI)
        nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante = informations_occupant_courant(ligne_G2GAI)

        # S'il y a quelqu'un en N-1 dans G2GAI
        if nigend_precedent.strip() != '':

            # Si les nigneds sont égaux en N-1 et N dans G2GAI
            if nigend_precedent == nigend_courant:

                # Parcourir les lignes du fichier GMBI
                for ligne_GMBI in donnees_fichierGMBI:

                    # S'il s'agit d'une partie principale 
                    if ("partie" in ligne_GMBI[18].lower() and
                        ligne_GMBI[3].strip() == ''and 
                        ligne_GMBI[2] not in valeurs_gmbi_traitees):

                        # Appel de la  focntion pour initialisation des variable de GMBI
                        departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI = informations_logement_GMBI(ligne_GMBI)

                        # Chercher une correspondance entre la line de G2GAI avec celle de GMBI
                        if (departement_logement_G2GAI == departement_local_GMBI  and
                            (fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[49]) == 100) and
                            premier_prenom_precedent_G2GAI in ligne_GMBI):

                            # Appel de la fonction pour vérifier la date d'arrivée
                            if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                                # Appel de la fonction pour copier la ligne et mettre "X" dans la cellule declarer
                                nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)

                                # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                                mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI)

                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                # Écrire la ligne modifiée dans le nouveau fichier 
                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité
                                valeurs_g2gai_traitees.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées
                                valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées
                            
                            else:
                                ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)
                                valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées

                            for ligne_GMBI in donnees_fichierGMBI:
                                
                                # S'il ne s'agit pas d'une partie principale 
                                if "partie" not in ligne_GMBI[18].lower() and ligne_GMBI[3].strip() != '':

                                    # Recherhcer les "dépendances" affectées à ce local
                                    if (departement_local_GMBI == ligne_GMBI[4] and
                                        ligne_GMBI[2] not in valeurs_gmbi_traitees and
                                        numero_fiscal_GMBI == ligne_GMBI[3]):

                                        if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                                            # Créer une nouvelle ligne avec les modifications
                                            nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)

                                            # if (nom_precedent_G2GAI in ligne_GMBI and
                                            if((fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[49]) == 100) and
                                                premier_prenom_precedent_G2GAI in ligne_GMBI):

                                                # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                                                mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI)

                                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                                # Écrire la ligne modifiée dans le nouveau fichier
                                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                                valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité

                                            else:
                                                # Créer une nouvelle ligne avec les modifications nécessaires
                                                # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                                                nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                                                nouvelle_ligne[0] = "Pareil Surpime L"  # A ENLEVER
                                                nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1

                                                # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                                                mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI)

                                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                                # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                                                if nouvelle_ligne[49].strip() != '':
                                                    nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                                                # Écrire la ligne modifiée dans le nouveau fichier
                                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                                                # Renseigner le nouvel occupant
                                                nouvelle_ligne[0] = "Pareil Ajout L"  # A ENLEVER
                                                nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                                                # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                                                nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                                                nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                                nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1
                                                # nouvelle_ligne[34] = ""  # Suppression de l'Id (dans la version 2023-2024 iln'y en a pas)
                                                nouvelle_ligne[42:45] = [""] * 3  # Vider AQ; AR; AS
                                                nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2

                                                # Écrire la ligne modifiée dans le nouveau fichier
                                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                                valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité
                                                valeurs_g2gai_traitees.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées
                                                valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées

                                        else:
                                            ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)
                                            valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées

                            break

            else:
                # Parcourir les lignes du fichier GMBI
                for ligne_GMBI in donnees_fichierGMBI:

                    # S'il s'agit d'une partie principale
                    if ("partie" in ligne_GMBI[18].lower() and
                        ligne_GMBI[3]==""and 
                        ligne_GMBI[2] not in valeurs_gmbi_traitees):

                        # Appel de la  focntion pour initialisation des variable de GMBI
                        departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI = informations_logement_GMBI(ligne_GMBI)

                        # Chercher une correspondance entre la ligne de G2GAI avec celle de GMBI
                        if (departement_logement_G2GAI == departement_local_GMBI  and
                            # nom_precedent_G2GAI in ligne_GMBI and
                            (fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[49]) == 100) and
                            premier_prenom_precedent_G2GAI in ligne_GMBI):

                            if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                                # Créer une nouvelle ligne avec les modifications nécessaires
                                # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                                nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                                nouvelle_ligne[0] = "Different Supprime PP"  # A ENLEVER
                                nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1

                                # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                                mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI)

                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                                if nouvelle_ligne[49].strip() != '':
                                    nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                                # Écrire la ligne modifiée dans le nouveau fichier
                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                                # Renseigner le nouvel occupant
                                nouvelle_ligne[0] = "Different Ajout PP"  # A ENLEVER
                                nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                                # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                                nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                                nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                                # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                # CHANGER L'ID SPI
                                nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                                # Vider l'Id Spi_1
                                # nouvelle_ligne[34] = ""  # Suppression de l'Id (dans la version 2023-2024 iln'y en a pas)

                                # Vider le Spi_2
                                nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2

                                # Écrire la ligne modifiée dans le nouveau fichier
                                ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité
                                valeurs_g2gai_traitees.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées
                                valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées

                            else:
                                ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)
                                valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées

                            for ligne_GMBI in donnees_fichierGMBI:
                                
                                # S'il ne s'agit pas d'une partie principale 
                                if "partie" not in ligne_GMBI[18].lower() and ligne_GMBI[3].strip() != '':

                                    # Recherhcer les "dépendances" affectées à ce local
                                    if (departement_local_GMBI == ligne_GMBI[4] and
                                        ligne_GMBI[2] not in valeurs_gmbi_traitees and
                                        numero_fiscal_GMBI == ligne_GMBI[3]):

                                        if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                                            # Créer une nouvelle ligne avec les modifications nécessaires
                                            # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                                            nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                                            nouvelle_ligne[0] = "Different Supprime L"  # A ENLEVER
                                            nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1

                                            # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                                            mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI)

                                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                            # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                                            if nouvelle_ligne[49].strip() != '':
                                                nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                                            # Écrire la ligne modifiée dans le nouveau fichier
                                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                                            nouvelle_ligne[0] = "Different Ajout L"  # A ENLEVER
                                            nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                                            # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                                            nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                                            nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                                            # CHANGER L'ID SPI
                                            nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                                            # Vider l'Id Spi_1
                                            # nouvelle_ligne[34] = ""  # Suppression de l'Id (dans la version 2023-2024 iln'y en a pas)

                                            # Vider le Spi_2
                                            nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2

                                            # Écrire la ligne modifiée dans le nouveau fichier
                                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                            valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité
                                        
                                        else:
                                            ajouter_gendarme_cause(nouveau_fichier, ligne_GMBI, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, numero_logement_G2GAI, date_arrivee, valeurs_gmbi_traitees, valeurs_g2gai_traitees)
                                            valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées

# %% [markdown]
# # Recherche des locaux associés aux logements de l'année précédente

# %%
# Locaux associers aux logements traités 
# Parcourir les lignes du fichier G2GAI
for ligne_G2GAI in donnees_fichierG2GAI:

    # Si le logement est Domaniale
    if ligne_G2GAI[16] == "D" and ligne_G2GAI[12] in valeurs_g2gai_traitees2023:
        
        # Appel des focntion pour initialisation des variable de G2GAI
        departement_logement_G2GAI, numero_logement_G2GAI = informations_logement_G2GAI(ligne_G2GAI)
        nigend_precedent, nom_precedent_G2GAI, prenom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente = informations_occupant_precedent(ligne_G2GAI)
        nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante = informations_occupant_courant(ligne_G2GAI)

        # Parcourir les lignes du fichier GMBI
        for ligne_GMBI in donnees_fichierGMBI:

            # S'il s'agit d'une partie principale 
            if "partie" not in ligne_GMBI[18].lower() and ligne_GMBI[3].strip() == '':

                # Appel de la  focntion pour initialisation des variable de GMBI
                departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI = informations_logement_GMBI(ligne_GMBI)

                # Chercher une correspondance entre la ligne de G2GAI avec celle de GMBI
                if (departement_logement_G2GAI == departement_local_GMBI and 
                    numero_fiscal_GMBI not in valeurs_gmbi_traitees and
                    # nom_precedent_G2GAI in ligne_GMBI and
                    (fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[35]) == 100 or fuzz.partial_token_sort_ratio(nom_precedent_G2GAI, ligne_GMBI[49]) == 100) and
                    premier_prenom_precedent_G2GAI in ligne_GMBI):

                    if verifier_date_arrivee(ligne_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_GMBI):

                        # Si les nigneds sont égaux en N-1 et N dans G2GAI
                        if nigend_precedent == nigend_courant:

                            # Créer une nouvelle ligne avec les modifications
                            nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)

                            # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                            mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI)

                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                            recuperer_idGroupLoc_et_assigner(donnees_fichierGMBI, departement_local_GMBI, valeurs_gmbi_traitees, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, nouvelle_ligne)

                            # Écrire la ligne modifiée dans le nouveau fichier 
                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                            valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité

                        else:
                            # Créer une nouvelle ligne avec les modifications nécessaires
                            # nouvelle_ligne = creer_nouvelle_ligne(ligne_GMBI)
                            nouvelle_ligne = ligne_GMBI[:]  # A ENLEVER
                            nouvelle_ligne[0] = "Local Nom Supprime"  # A ENLEVER
                            nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1

                            # Appel de la fonction qui cherche où la correspondance a été trouvée pour mettre la date de naissance du gendarme
                            mettre_date_naissance_gendarme(nouvelle_ligne, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, date_naissance_precedente, spi1_nom_GMBI, spi1_prenom_GMBI)

                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                            # Vérifier s'il y a quelqu'un en Spi_2 pour mettre une date de départ
                            if nouvelle_ligne[49].strip() != '':
                                nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2

                            recuperer_idGroupLoc_et_assigner(donnees_fichierGMBI, departement_local_GMBI, valeurs_gmbi_traitees, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, nouvelle_ligne)

                            # Écrire la ligne modifiée dans le nouveau fichier
                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                            # Renseigner le nouvel occupant
                            nouvelle_ligne[0] = "Local Nom Ajout"  # A ENLEVER
                            nouvelle_ligne[35] = nom_courant_G2GAI  # Mettre le Nom du nouveau gendarme
                            # premier_prenom_courant_G2GAI = prenom_courant_G2GAI.split(' ')[0]
                            nouvelle_ligne[37] = premier_prenom_courant_G2GAI  # Mettre le Prénom du nouveau gendarme
                            nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme

                            # Appel de la pour remplire la ligne en fonction de la vacance ou non et remplisage de la cellule observation
                            determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)

                            # CHANGER L'ID SPI
                            nouvelle_ligne[45] = date_arrivee  # Mettre la date d'arrivée pour Spi_1

                            # Vider l'Id Spi_1
                            # nouvelle_ligne[34] = ""  # Suppression de l'Id (dans la version 2023-2024 iln'y en a pas)

                            # Vider le Spi_2
                            nouvelle_ligne[46:61] = [""] * 15  # Vider toutes les données du Spi_2

                            # Écrire la ligne modifiée dans le nouveau fichier
                            ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                            valeurs_gmbi_traitees.add(numero_fiscal_GMBI)  # Ajouter la ligne de GMBI à celles déjà traité

                    else:
                        nouvelle_ligne = ligne_GMBI[:]
                        nouvelle_ligne[1] = "Erreur Local Nom"
                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                        nouvelle_ligne[0] = "Ajout Erreur Local Nom"
                        nouvelle_ligne[1] = ""
                        nouvelle_ligne[35] = nom_courant_G2GAI
                        nouvelle_ligne[37] = premier_prenom_courant_G2GAI
                        nouvelle_ligne[38] = date_naissance_courante  # Mettre la Date de naissaince du nouveau gendarme
                        determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                        recuperer_idGroupLoc_et_assigner(donnees_fichierGMBI, departement_local_GMBI, valeurs_gmbi_traitees, nom_precedent_G2GAI, premier_prenom_precedent_G2GAI, nouvelle_ligne)
                        nouvelle_ligne[45] = date_arrivee
                        nouvelle_ligne[46:61] = [""] * 15
                        ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                        valeurs_gmbi_traitees.add(ligne_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traité
                        valeurs_g2gai_traitees.add(numero_logement_G2GAI)
                        valeurs_g2gai_traitees2023.add(numero_logement_G2GAI)  # Ajouter la ligne de G2GAI à celles déjà traitées
# Locaux associers aux logements traités 
# 2023

# %% [markdown]
# # Recherche des logements et locaux du fichier des abandons dans GMBI

# %%
# En cours d'abandon G2GAI
# Parcourir les lignes du fichier abandon
similarite_minimum = 100
while similarite_minimum >= 70:
    print(f"{similarite_minimum} total")
    # Parcourir les lignes du fichier abandon
    for ligne_abandon in donnees_fichierAbandon:

        # Si le logement n'a pas déjà été traité
        if ligne_abandon[0] not in valeurs_abandon_traitees:

            numero_logement_abandon = ligne_abandon[0]
            code_ui_abandon = ligne_abandon[1]
            if numero_logement_abandon.startswith("1 0") and numero_logement_abandon[4] == "0":
                departement_logement_abandon = numero_logement_abandon[3:4]
            elif numero_logement_abandon.startswith("1"):
                departement_logement_abandon = numero_logement_abandon[2:4]
            else:
                departement_logement_abandon = numero_logement_abandon[2:5]
            departement_logement_abandon = convertir_code_departement_corse(departement_logement_abandon)
            commune_abandon = ligne_abandon[5]
            adresse_abandon = ligne_abandon[3]

            # Extraire les valeurs de l'adresse de la colonne J de GMBI
            adresse_GMBI = [ligne for ligne in donnees_fichierGMBI
                            if ligne[4] == departement_logement_abandon
                                and (fuzz.partial_token_sort_ratio(ligne[6], ligne_abandon[5] ) >= 85 or fuzz.token_set_ratio(ligne[6], ligne_abandon[5] ) >= 85)
                                and ligne[2] not in valeurs_gmbi_traitees
                                and ligne[3] == ""
                                and "partie" in ligne[18].lower()]

            if adresse_GMBI:
                for ligne_GMBI in adresse_GMBI:
                    meilleure_correspondance, score = process.extractOne(adresse_abandon, [ligne_GMBI[9]])

                    # Si le score est supérieur au seuil de similarité minimum
                    if score >= similarite_minimum:
                        print(f"Valeur trouvée: {meilleure_correspondance} Score: {score}, Pour {adresse_abandon}")

                        # Dupliquer toutes les lignes avec le même libellé d'adresse de GMBI
                        for ligne_similaire_GMBI in donnees_fichierGMBI:
                            if (ligne_similaire_GMBI[9] == ligne_GMBI[9] and
                                ligne_similaire_GMBI[2] not in valeurs_gmbi_traitees):  # Vérifier si les adresses sont les mêmes et que la ligne n'a pas encore été traitée
                                # Traitement de la correspondance
                                departement_local_GMBI, numero_fiscal_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI = informations_logement_GMBI(ligne_similaire_GMBI)
                                commune_GMBI = ligne_similaire_GMBI[6]
                                adresse_GMBI = ligne_similaire_GMBI[9]

                                if verifier_date_arrivee(ligne_similaire_GMBI, date_arrivee) and verifier_vacance_occupation(ligne_similaire_GMBI):

                                    nouvelle_ligne = ligne_similaire_GMBI[:]  # Dupliquer la ligne pour éviter de modifier l'original
                                    nouvelle_ligne[0] = "abandonPARTI"  # A ENLEVER
                                    determiner_type_occupation(nouvelle_ligne, numero_logement_G2GAI)
                                    nouvelle_ligne[46] = date_depart  # Mettre la date de départ pour spi_1
                                    if nouvelle_ligne[49].strip() != '':
                                        nouvelle_ligne[60] = date_depart  # Mettre la date de départ pour spi_2
                                    nouvelle_ligne[64] = f"Abandon nom de rue G2GAI : {adresse_abandon} numero UI : {code_ui_abandon}"
                                    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)

                                    # Marquer la ligne de GMBI comme traitée
                                    valeurs_gmbi_traitees.add(ligne_similaire_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traitées

                                else:
                                    # Gérer le cas où la date d'arrivée ou l'occupation est incorrecte
                                    nouvelle_ligne = ligne_similaire_GMBI[:]
                                    nouvelle_ligne[1] = "abandon"
                                    nouvelle_ligne[64] = f"Abandon nom de rue G2GAI : {adresse_abandon}"
                                    ecrire_ligne_csv(nouveau_fichier, nouvelle_ligne)
                                    valeurs_gmbi_traitees.add(ligne_similaire_GMBI[2])  # Ajouter la ligne de GMBI à celles déjà traitées
                                
                        # Marquer toutes les lignes Abandon avec le même libellé d'adresse comme traitées
                        valeurs_abandon_traitees.update([x[0] for x in donnees_fichierAbandon if x[3] == adresse_abandon])

    similarite_minimum -= 5
# En cours d'abandon G2GAI
# Out:
# 100 total
# 95 total
# 90 total
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# Valeur trouvée: BD POYAT Score: 90, Pour Poyat
# 85 total
# 80 total
# 75 total
# 70 total

# %% [markdown]
# # Recherche de correspondance avec les adresses entre G2GAI et GMBI

# %%
# Correspondance adresse
# Traitement des lignes où il n'y à personne en N-1 ou qui n'ont pas été traitées
similarite_minimum = 100
max_ecart_etage = 3
max_ecart_pieces = 2
max_ecart_surface = 30

while similarite_minimum >= 75:
    print(f"{similarite_minimum} TEST")
    # Parcourir les lignes du fichier G2GAI
    for ligne_G2GAI in donnees_fichierG2GAI:

        # Si le logement est Domaniale et n'a pas été traité
        if ligne_G2GAI[16] == "D" and ligne_G2GAI[12] not in valeurs_g2gai_traitees:

            # Appel à la fonction pour initialisation des variables adresse
            (departement_logement_G2GAI, numero_logement_G2GAI, nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, adresse_G2GAI, adresse_G2GAI_caracteres, adresse_G2GAI_chiffres, etage_G2GAI, surface_G2GAI, ecart_maximal_surface, nbr_pieces_G2GAI, ecart_maximal_piece) = initialiser_variables_adresse(ligne_G2GAI)

            # Extraire les valeurs de l'adresse de la colonne J de GMBI
            adresse_GMBI = [ligne[9] for ligne in donnees_fichierGMBI
                                if ligne[4] == departement_logement_G2GAI
                                    and (fuzz.partial_token_sort_ratio(ligne[6], ligne_G2GAI[10] ) >= 85 or fuzz.token_set_ratio(ligne[6], ligne_G2GAI[10] ) >= 85)
                                    and ligne[2] not in valeurs_gmbi_traitees
                                    and ligne[3] == ""
                                    and "partie" in ligne[18].lower()]

            # Utiliser la bibliothèque pour trouver la meilleure correspondance
            correspondance  = process.extractOne(adresse_G2GAI_caracteres, adresse_GMBI)
            
            if correspondance is not None:
                meilleure_correspondance, score = correspondance
                print(meilleure_correspondance)

                # Si le score est supérieur au seuil de similarité minimum
                if score >= similarite_minimum:
                    # print(f"Valeur trouvée: {meilleure_correspondance}, Score: {score}, Pour {adresse_G2GAI}")

                    # Récupérer la première ligne correspondante dans GMBI
                    for ecart_surface in range(max_ecart_surface + 1):                        
                        for ecart_pieces in range(max_ecart_pieces + 1):
                            for ecart_etage in range(max_ecart_etage + 1):
                                ligne_GMBI = next((ligne for ligne in donnees_fichierGMBI
                                                    if meilleure_correspondance in ligne
                                                    and ligne[2] not in valeurs_gmbi_traitees
                                                    and ligne[3] == ""
                                                    and "partie" in ligne[18].lower()
                                                    and abs(int(ligne[21]) - int(surface_G2GAI)) == ecart_surface
                                                    and abs(int(ligne[20]) - int(nbr_pieces_G2GAI)) == ecart_pieces
                                                    and abs(int(ligne[12]) - int(etage_G2GAI)) == ecart_etage), None)
                                if ligne_GMBI:
                                    break
                            if ligne_GMBI:
                                break
                        if ligne_GMBI:
                            break

                    if ligne_GMBI :
                        print(ligne_GMBI)

                        # Traitement de la correspondance
                        traiter_correspondance(ligne_GMBI, date_arrivee, date_depart, numero_logement_G2GAI, adresse_G2GAI_caracteres, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, nouveau_fichier, valeurs_gmbi_traitees, valeurs_g2gai_traitees, numero_fiscal_GMBI, departement_local_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI)

    similarite_minimum -= 5
# Correspondance adresse
# Out:
# 100 TEST
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE MANTE
# RUE DU BUGEY
# RUE DE DOMPARON
# ['', '', '011730062449F', '', '1', 'AIN', 'GEX', '105', '', 'RUE DE DOMPARON', '10', '1', '0', '1003', '', 'AK', '35', 'AP', 'Partie principale', '', '6', '73', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE DOMPARON
# ['', '', '011730062453A', '', '1', 'AIN', 'GEX', '105', '', 'RUE DE DOMPARON', '10', '1', '2', '1002', '', 'AK', '35', 'AP', 'Partie principale', '', '6', '76', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'LE LOUER', '', 'TELIO', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE DOMPARON
# ['', '', '011730278639F', '', '1', 'AIN', 'GEX', '105', '', 'RUE DE DOMPARON', '8', '1', '2', '1001', '', 'AK', '37', 'AP', 'Partie principale-Toiture terrasse', '', '6', '92', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'SERGENT', '', 'KEVIN', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE DOMPARON
# ['', '', '011730062455S', '', '1', 'AIN', 'GEX', '105', '', 'RUE DE DOMPARON', '11', '1', '0', '1001', '', 'AK', '35', 'AP', 'Partie principale', '', '7', '95', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'GASPARAC', '', 'AMANDINE', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PHILIBERT LE BEAU
# ['', '', '013040317830R', '', '1', 'AIN', 'PONT-D AIN', '9', '', 'RUE PHILIBERT LE BEAU', 'B', '1', '0', '1004', '', 'ZC', '382', 'MA', 'Cave-Partie principale', '', '5', '71', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# PL DU SORGIA
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ANDRE TERNYNCK
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# RUE ALBERT 1ER
# AV CHARLES DE GAULLE
# ['', '', '024080043010B', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'B', '1', '1', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '5', '56', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2019', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043000H', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'A', '1', '2', '1001', '', 'AV', '199', 'AP', 'Partie principale', '', '5', '56', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'BLAISE', '', 'MAXENCE', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043035S', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'D', '1', '2', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '5', '56', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043037H', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'D', '1', '3', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '5', '56', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043001D', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'A', '1', '2', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '6', '66', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'AMOURETTE', '', 'CAMILLE', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043025Y', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'C', '1', '3', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '6', '66', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'LEVEAU', '', 'JUSTINE', '', '', '', '', '', '', '', '01/01/2020', '', '1', '', 'GALVAN', '', 'THOMAS', '', '', '', '', '', '', '', '01/01/2020', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043005L', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'A', '1', '4', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '6', '66', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'FLAMANT', '', 'CHLOE', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043027P', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'C', '1', '4', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '6', '66', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017715S', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'C', '1', '2', '2001', '', 'AY', '296', 'AP', 'Partie principale', '', '6', '75', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '01/01/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080043032E', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'D', '1', '1', '1001', '', 'AV', '199', 'AP', 'Partie principale', '', '7', '76', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080042999A', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'A', '1', '1', '2001', '', 'AV', '199', 'AP', 'Partie principale', '', '7', '76', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'GARCIA', '', 'HELENE', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017740U', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'E', '1', '0', '1002', '', 'AY', '296', 'AP', 'Partie principale', '', '6', '82', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'MINISTERE DE L INTERIEUR GENDARMERIE', '7113', '01/01/2017', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017803W', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'I', '1', '0', '1002', '', 'AY', '296', 'AP', 'Partie principale', '', '6', '82', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'MINISTERE DE L INTERIEUR GENDARMERIE', '7113', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017748J', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'E', '1', '1', '1001', '', 'AY', '296', 'AP', 'Partie principale', '', '6', '83', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'MINISTERE DE L INTERIEUR GENDARMERIE', '7113', '01/01/2014', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212288A', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '2', '1', '13001', '', 'AV', '199', 'AP', 'Partie principale', '', '6', '84', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212294L', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '3', '1', '22001', '', 'AV', '199', 'AP', 'Partie principale', '', '6', '84', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017751H', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'E', '1', '2', '2001', '', 'AY', '296', 'AP', 'Partie principale', '', '7', '94', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'MINISTERE DE L INTERIEUR GENDARMERIE', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017817X', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'I', '1', '3', '1001', '', 'AY', '296', 'AP', 'Partie principale', '', '7', '94', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'MINISTERE DE L INTERIEUR GENDARMERIE', '7113', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017796K', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'H', '1', '1', '1001', '', 'AY', '296', 'AP', 'Partie principale', '', '6', '85', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '', 'MINISTERE DE L INTERIEUR GENDARMERIE', '7113', '24/03/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212306A', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '4', '3', '37001', '', 'AV', '199', 'AP', 'Partie principale', '', '8', '104', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212302T', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '4', '1', '33001', '', 'AV', '199', 'AP', 'Partie principale', '', '8', '104', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017853N', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'L', '1', '0', '2001', '', 'AY', '296', 'AP', 'Partie principale', '', '7', '107', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '01/01/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212285N', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '1', '3', '8001', '', 'AV', '199', 'AP', 'Partie principale', '', '8', '104', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212289W', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '2', '2', '14001', '', 'AV', '199', 'AP', 'Partie principale', '', '8', '104', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2019', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212291Z', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '2', '3', '16001', '', 'AV', '199', 'AP', 'Partie principale', '', '8', '104', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'ARAUJO-BRETON', '', 'BENJAMIN', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '081050017849U', '', '8', 'ARDENNES', 'CHARLEVILLE MEZIERES', '198', '', 'AV CHARLES DE GAULLE', 'K', '1', '4', '1001', '', 'AY', '296', 'AP', 'Partie principale', '', '7', '116', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'MINISTERE DE L INTERIEUR GENDARMERIE', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# ['', '', '024080212295G', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'I', '3', '1', '23001', '', 'AV', '199', 'AP', 'Partie principale', '', '8', '104', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV CHARLES DE GAULLE
# RUE QUENTIN BARRE
# ['', '', '026910065271H', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'A', '2', '1', '4001', '', 'AY', '1041', 'AP', 'Partie principale', '', '5', '67', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '02/10/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065321E', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'G', '1', '1', '49001', '', 'AY', '1041', 'AP', 'Partie principale', '', '5', '71', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'RENARD', '', 'FABIEN', '', '', '', '', '', '', '', '01/06/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065323W', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'G', '1', '2', '51001', '', 'AY', '1041', 'AP', 'Partie principale', '', '5', '71', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '31/08/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065270M', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'A', '2', '1', '3001', '', 'AY', '1041', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'MONET', '', 'CORENTIN', '', '', '', '', '', '', '', '19/09/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065309H', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'E', '1', '3', '39001', '', 'AY', '1041', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '28/09/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065281B', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'B', '1', '1', '13001', '', 'AY', '1041', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'LEBON', '', 'AIMERIC', '', '', '', '', '', '', '', '19/09/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065283T', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'B', '1', '2', '15001', '', 'AY', '1041', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'CARTY', '', 'THOMAS', '', '', '', '', '', '', '', '24/03/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065312G', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'F', '1', '0', '41001', '', 'AY', '1041', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '14/07/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065287A', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'C', '1', '0', '19001', '', 'AY', '1041', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '02/09/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065313C', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'F', '1', '0', '42001', '', 'AY', '1041', 'AP', 'Partie principale', '', '8', '96', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'CANESSE', '', 'CHLOE', '', '', '', '', '', '', '', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065331Y', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'H', '1', '1', '58001', '', 'AY', '1041', 'AP', 'Partie principale', '', '8', '96', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '13/09/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065315U', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'F', '1', '1', '44001', '', 'AY', '1041', 'AP', 'Partie principale', '', '8', '96', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '04/08/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065274V', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'A', '2', '3', '7001', '', 'AY', '1041', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'TANGUY', '', 'ALAN', '', '', '', '', '', '', '', '11/09/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065269E', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'A', '2', '0', '2001', '', 'AY', '1041', 'AP', 'Partie principale', '', '5', '67', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'ALEXANDRE', '', 'DORIAN', '', '', '', '', '', '', '', '21/08/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065288W', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'C', '1', '0', '20001', '', 'AY', '1041', 'AP', 'Partie principale', '', '5', '67', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'PEYRELONGUE', '', 'JADE', '', '', '', '', '', '', '', '01/09/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065324S', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'G', '1', '2', '52001', '', 'AY', '1041', 'AP', 'Partie principale', '', '5', '65', '', '', '', '', '', '', 'N', 'N', '', '', '1', '1', '', 'CHARLEMEIN', '', 'LUCAS', '', '', '', '', '', '', '', '20/03/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE QUENTIN BARRE
# ['', '', '026910065322A', '', '2', 'AISNE', 'SAINT QUENTIN', '180', '', 'RUE QUENTIN BARRE', 'G', '1', '1', '50001', '', 'AY', '1041', 'AP', 'Partie principale', '', '5', '65', '', '', '', '', '', '', 'N', 'N', '', '', '4', '1', '', 'GERARD', '', 'ROBIN', '', '', '', '', '', '', '', '04/09/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# AV DE LAON
# AV DE LAON
# AV DE LAON
# AV DE LAON
# AV DE LAON
# AV DE LAON
# AV DE LAON
# AV DE LAON
# AV DE LAON
# AV DE LAON
# BD DE SOLINS
# RUE DE PARIS
# ['', '', '031900071737U', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'G', '1', '0', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '5', '66', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071714V', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'F', '1', '0', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '5', '66', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071698L', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'E', '1', '0', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '5', '66', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2018', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071721B', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'F', '1', '2', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '5', '66', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071799W', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'K', '1', '0', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'BONILLA', '', 'THOMAS', '', '', '', '', '', '', '', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071636J', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'B', '1', '0', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071683P', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'D', '1', '2', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '01/01/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071649P', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'B', '1', '4', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071670J', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'C', '1', '4', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071804R', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'K', '1', '1', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071621M', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'A', '1', '2', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071671E', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'C', '1', '4', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071628G', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'A', '1', '4', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2019', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071756K', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'H', '1', '0', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071613K', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'A', '1', '0', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071634T', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'B', '1', '0', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071697R', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'E', '1', '0', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071680C', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'D', '1', '1', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071659H', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'C', '1', '1', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071803V', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'K', '1', '1', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071719Y', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'F', '1', '1', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2019', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071662G', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'C', '1', '2', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'SAPT', '', 'MATHIS', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071808Y', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'K', '1', '2', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2018', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900153666D', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'J', '1', '2', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071627L', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'A', '1', '3', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071809U', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'K', '1', '3', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2017', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071753Y', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'G', '1', '4', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071772P', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'H', '1', '4', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071691S', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'D', '1', '4', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2018', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071731V', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'F', '1', '4', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071770Y', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'H', '1', '3', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071645G', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'B', '1', '3', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2017', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071709E', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'E', '1', '3', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '6', '77', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071843U', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'O', '1', '2', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '8', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2019', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071830N', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'M', '1', '0', '1002', '', 'AD', '117', 'AP', 'Partie principale', '', '8', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2017', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071730Z', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'F', '1', '4', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'RICHARD', '', 'PIERRE-ALEXANDRE', '', '', '', '', '', '', '', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071630K', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'A', '1', '4', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071681Y', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'D', '1', '1', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071685F', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'D', '1', '2', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071693H', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'D', '1', '4', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071615B', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'A', '1', '0', '4001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'TALASSI', '', 'ALINE', '', '', '', '', '', '', '', '01/01/2016', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071761A', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'H', '1', '1', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071668F', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'C', '1', '3', '3001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071793X', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'J', '1', '4', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'DUBOST', '', 'JOANA', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071726E', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'F', '1', '3', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071789C', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'J', '1', '3', '2001', '', 'AD', '117', 'AP', 'Partie principale', '', '7', '92', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# ['', '', '031900071848X', '', '3', 'ALLIER', 'MOULINS', '118', '', 'RUE DE PARIS', 'P', '1', '2', '1001', '', 'AD', '117', 'AP', 'Partie principale', '', '9', '110', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DE PARIS
# RUE DES PAQUERETTES
# RUE DES PAQUERETTES
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# RUE MALDONAT
# AV DES MARRONNIERS
# ['', '', '040940029071T', '', '4', 'ALPES HAUTE PROVENCE', 'GREOUX-LES-BAINS', '17', '', 'AV DES MARRONNIERS', 'A', '1', '2', '2001', '', 'G', '1754', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'ETAT MIN DE LA DEFENSE', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DES MARRONNIERS
# ['', '', '040940029069P', '', '4', 'ALPES HAUTE PROVENCE', 'GREOUX-LES-BAINS', '17', '', 'AV DES MARRONNIERS', 'A', '1', '1', '2001', '', 'G', '1754', 'AP', 'Partie principale', '', '7', '88', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'ETAT MIN DE LA DEFENSE', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156335P', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '5', '1', '1', '2001', '', 'AR', '18', 'AP', 'Partie principale', '', '5', '71', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'HERZER', '', 'RODOLPHE', '', '', '', '', '', '', '', '01/01/2013', '', '1', '', 'BRAY', '', 'AURELIE', '', '', '', '', '', '', '', '01/01/2021', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156338B', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '5', '1', '2', '2001', '', 'AR', '18', 'AP', 'Partie principale', '', '5', '71', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156314G', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '4', '1', '1', '1001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '86', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156318P', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '4', '1', '3', '1001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '86', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156319K', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '4', '1', '3', '2001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '86', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156337F', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '5', '1', '2', '1001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '87', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156331G', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '5', '1', '0', '1001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '87', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156333Y', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '5', '1', '0', '3001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '87', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156336K', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '5', '1', '1', '3001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '87', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156334U', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '5', '1', '1', '1001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '87', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156254S', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '2', '1', '1', '4001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '88', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156285T', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '3', '1', '0', '1001', '', 'AR', '18', 'AP', 'Partie principale', '', '6', '99', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ['', '', '050230156248F', '', '5', 'HAUTES ALPES', 'BRIANCON', '13', '', 'RUE PASTEUR', '2', '1', '0', '2001', '', 'AR', '18', 'AP', 'Partie principale', '', '8', '103', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE PASTEUR
# ...
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# AV DU GENERAL DE GAULLE
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# BD CHANZY
# BD CHANZY
# AV DU GENERAL LECLERC
# AV DU GENERAL LECLERC
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# 75 TEST
# RUE ANDRE TERNYNCK
# AV CHARLES DE GAULLE
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DE PARIS
# RUE DES PAQUERETTES
# RUE DES PAQUERETTES
# RTE DU QUEYRAS
# RTE DU QUEYRAS
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# AV SIDI BRAHIM
# SUEIL
# AV SAINTE MARGUERITE
# AV SAINTE MARGUERITE
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# AV DU GENERAL DE GAULLE
# ['', '', '070420023429T', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'R', '3', '3', '1003', '', 'AR', '230', 'AP', 'Partie principale', '', '4', '47', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'MASSAUDET', '', 'LIONNEL', '', '', '', '', '', '', '', '01/01/2015', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023369C', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'C', '2', '3', '2048', '', 'AR', '230', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023335P', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'A', '3', '3', '1017', '', 'AR', '230', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023411J', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'F', '3', '4', '2086', '', 'AR', '230', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023347Z', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'B', '2', '3', '2028', '', 'AR', '230', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'VILLEY', '', 'CELINE', '', '', '', '', '', '', '', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023322J', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'A', '2', '1', '2004', '', 'AR', '230', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023451H', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'S', '2', '3', '2024', '', 'AR', '230', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023338B', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'A', '3', '4', '2020', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023414W', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'R', '2', '0', '2088', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'REMY', '', 'AXEL', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023353K', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'B', '3', '1', '2034', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023348V', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'B', '2', '4', '1029', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023404C', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'F', '3', '1', '1079', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023332C', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'A', '3', '1', '2014', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023323E', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'A', '2', '2', '1005', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023366R', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'C', '2', '2', '1045', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023368G', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'C', '2', '3', '1047', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023359J', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'B', '3', '4', '2040', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023410N', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'F', '3', '4', '1085', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023344M', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'B', '2', '2', '1025', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023375N', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'D', '2', '1', '1053', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '78', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'BLEUZE', '', 'ROXANNE', '', '', '', '', '', '', '', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023390X', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'E', '2', '3', '2066', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '78', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'HOAREAU', '', 'MARIE', '', '', '', '', '', '', '', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023436Z', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'S', '1', '1', '1009', '', 'AR', '230', 'AP', 'Partie principale', '', '7', '87', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023394E', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'F', '2', '1', '1069', '', 'AR', '230', 'AP', 'Partie principale', '', '7', '87', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023440U', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'S', '1', '3', '1013', '', 'AR', '230', 'AP', 'Partie principale', '', '7', '87', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2020', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023434H', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'S', '1', '0', '1007', '', 'AR', '230', 'AP', 'Partie principale', '', '7', '87', '', '', '', '', '', '', '', '', '', '', '', '1', '', 'MAUREL', '', 'FREDERIC', '', '', '', '', '', '', '', '01/01/2015', '', '1', '', 'ALMELA', '', 'DELPHINE', '', '', '', '', '', '', '', '01/01/2015', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023400V', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'F', '2', '4', '1075', '', 'AR', '230', 'AP', 'Partie principale', '', '7', '87', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023364Z', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '3', '', 'AV DU GENERAL DE GAULLE', 'C', '2', '1', '1043', '', 'AR', '230', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023456L', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '9036', '', 'AV DU GENERAL DE GAULLE', 'T', '2', '1', '1028', '', 'AR', '230', 'AP', 'Partie principale', '', '8', '112', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '', 'GPT DE GENDARMERIE DEPARTEMENTALE 07', '7113', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023457G', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '9036', '', 'AV DU GENERAL DE GAULLE', 'T', '2', '2', '1029', '', 'AR', '230', 'AP', 'Partie principale', '', '8', '112', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL DE GAULLE
# ['', '', '070420023455R', '', '7', 'ARDECHE', 'BOURG-SAINT-ANDEOL', '9036', '', 'AV DU GENERAL DE GAULLE', 'T', '2', '0', '1027', '', 'AR', '230', 'AP', 'Partie principale', '', '7', '95', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# BD CHANZY
# BD CHANZY
# AV DU GENERAL LECLERC
# AV DU GENERAL LECLERC
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING

# %%
# Correspondance adresse
# Traitement des lignes où il n'y à personne en N-1 ou qui n'ont pas été traitées
similarite_minimum = 100
dernier_max_ecart_etage = 5
dernier_max_ecart_pieces = 5
dernier_max_ecart_surface = 75

while similarite_minimum >= 75:
    print(f"{similarite_minimum} TEST")
    # Parcourir les lignes du fichier G2GAI
    for ligne_G2GAI in donnees_fichierG2GAI:

        # Si le logement est Domaniale et n'a pas été traité
        if ligne_G2GAI[16] == "D" and ligne_G2GAI[12] not in valeurs_g2gai_traitees:

            # Appel à la fonction pour initialisation des variables adresse
            (departement_logement_G2GAI, numero_logement_G2GAI, nigend_courant, nom_courant_G2GAI, prenom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, adresse_G2GAI, adresse_G2GAI_caracteres, adresse_G2GAI_chiffres, etage_G2GAI, surface_G2GAI, ecart_maximal_surface, nbr_pieces_G2GAI, ecart_maximal_piece) = initialiser_variables_adresse(ligne_G2GAI)

            # Extraire les valeurs de l'adresse de la colonne J de GMBI
            adresse_GMBI = [ligne[9] for ligne in donnees_fichierGMBI
                                if ligne[4] == departement_logement_G2GAI
                                    and (fuzz.partial_token_sort_ratio(ligne[6], ligne_G2GAI[10] ) >= 85 or fuzz.token_set_ratio(ligne[6], ligne_G2GAI[10] ) >= 85)
                                    and ligne[2] not in valeurs_gmbi_traitees
                                    and ligne[3] == ""
                                    and "partie" in ligne[18].lower()]

            # Utiliser la bibliothèque pour trouver la meilleure correspondance
            correspondance  = process.extractOne(adresse_G2GAI_caracteres, adresse_GMBI)
            
            if correspondance is not None:
                meilleure_correspondance, score = correspondance
                print(meilleure_correspondance)

                # Si le score est supérieur au seuil de similarité minimum
                if score >= similarite_minimum:
                    # print(f"Valeur trouvée: {meilleure_correspondance}, Score: {score}, Pour {adresse_G2GAI}")

                    # Récupérer la première ligne correspondante dans GMBI
                    for ecart_surface in range(30, dernier_max_ecart_surface + 1):                        
                        for ecart_pieces in range(dernier_max_ecart_pieces + 1):
                            for ecart_etage in range(dernier_max_ecart_etage + 1):
                                ligne_GMBI = next((ligne for ligne in donnees_fichierGMBI
                                                    if meilleure_correspondance in ligne
                                                    and ligne[2] not in valeurs_gmbi_traitees
                                                    and ligne[3] == ""
                                                    and "partie" in ligne[18].lower()
                                                    and abs(int(ligne[21]) - int(surface_G2GAI)) <= ecart_surface
                                                    and abs(int(ligne[20]) - int(nbr_pieces_G2GAI)) == ecart_pieces
                                                    and abs(int(ligne[12]) - int(etage_G2GAI)) == ecart_etage), None)
                                if ligne_GMBI:
                                    break
                            if ligne_GMBI:
                                break
                        if ligne_GMBI:
                            break

                    if ligne_GMBI :
                        print(ligne_GMBI)

                        # Traitement de la correspondance
                        traiter_correspondance(ligne_GMBI, date_arrivee, date_depart, numero_logement_G2GAI, adresse_G2GAI_caracteres, nom_courant_G2GAI, premier_prenom_courant_G2GAI, date_naissance_courante, nouveau_fichier, valeurs_gmbi_traitees, valeurs_g2gai_traitees, numero_fiscal_GMBI, departement_local_GMBI, spi1_nom_GMBI, spi1_prenom_GMBI)

    similarite_minimum -= 10
# Correspondance adresse
# Out:
# 100 TEST
# RUE ANDRE TERNYNCK
# AV CHARLES DE GAULLE
# ['', '', '024080132119M', '', '2', 'AISNE', 'LAON', '30', '', 'AV CHARLES DE GAULLE', 'G', '1', '0', '1001', '', 'AV', '199', 'MA', 'Partie principale-Garage-Toiture terrasse-Grenier-Cave', '', '10', '158', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# RUE DE PARIS
# RUE DES PAQUERETTES
# RUE DES PAQUERETTES
# RTE DU QUEYRAS
# RTE DU QUEYRAS
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# AV SIDI BRAHIM
# ['', '', '060691002581K', '', '6', 'ALPES-MARITIMES', 'GRASSE', '4', '', 'AV SIDI BRAHIM', 'A', '4', '0', '1001', '', 'BY', '289', 'AP', 'Partie principale', '', '7', '100', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '157000019', 'D G DE LA GENDARMERIE NATIONALE', '7150', '01/01/2023', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# SUEIL
# AV SAINTE MARGUERITE
# ['', '', '060880683534W', '', '6', 'ALPES-MARITIMES', 'NICE', '168', '', 'AV SAINTE MARGUERITE', '10', '1', '0', '1001', '', 'NP', '198', 'AP', 'Partie principale', '', '7', '116', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV SAINTE MARGUERITE
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# BD CHANZY
# BD CHANZY
# AV DU GENERAL LECLERC
# AV DU GENERAL LECLERC
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# 90 TEST
# RUE ANDRE TERNYNCK
# ['', '', '021730017535R', '', '2', 'AISNE', 'CHAUNY', '66', '', 'RUE ANDRE TERNYNCK', '29', '1', '1', '4001', '', 'AO', '7', 'AP', 'Partie principale', '', '5', '60', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DU COMMANDANT GUY BIELER
# RUE DU COMMANDANT GUY BIELER
# ['', '', '026910064266F', '', '2', 'AISNE', 'SAINT QUENTIN', '14', '', 'RUE DU COMMANDANT GUY BIELER', '40', '3', '0', '73001', '', 'AY', '176', 'AP', 'Partie principale', '', '5', '63', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DU COMMANDANT GUY BIELER
# RUE DE PARIS
# RUE DES PAQUERETTES
# RUE DES PAQUERETTES
# RTE DU QUEYRAS
# RTE DU QUEYRAS
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# BD DE LA REPUBLIQUE
# SUEIL
# AV SAINTE MARGUERITE
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# BD CHANZY
# BD CHANZY
# AV DU GENERAL LECLERC
# ['', '', '092250021610V', '', '9', 'ARIEGE', 'PAMIERS', '1', '', 'AV DU GENERAL LECLERC', '11', '1', '0', '3001', '', 'I', '789', 'AP', 'Partie principale', '', '6', '73', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# AV DU GENERAL LECLERC
# ['', '', '092250021634P', '', '9', 'ARIEGE', 'PAMIERS', '1', '', 'AV DU GENERAL LECLERC', '14', '1', '0', '3001', '', 'I', '789', 'AP', 'Partie principale', '', '6', '73', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# 80 TEST
# RUE DU COMMANDANT GUY BIELER
# ['', '', '026910064218E', '', '2', 'AISNE', 'SAINT QUENTIN', '14', '', 'RUE DU COMMANDANT GUY BIELER', '31', '2', '1', '25001', '', 'AY', '176', 'AP', 'Partie principale', '', '5', '63', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# RUE DU COMMANDANT GUY BIELER
# RUE DE PARIS
# RUE DES PAQUERETTES
# RUE DES PAQUERETTES
# RTE DU QUEYRAS
# RTE DU QUEYRAS
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# RUE DES FUSILLES
# BD DE LA REPUBLIQUE
# ['', '', '060290241494V', '', '6', 'ALPES-MARITIMES', 'CANNES', '122', '', 'BD DE LA REPUBLIQUE', '4', '1', '0', '1001', '', 'DH', '178', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# BD DE LA REPUBLIQUE
# ['', '', '060290241513R', '', '6', 'ALPES-MARITIMES', 'CANNES', '122', '', 'BD DE LA REPUBLIQUE', '6', '1', '1', '2001', '', 'DH', '178', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# BD DE LA REPUBLIQUE
# ['', '', '060290241490M', '', '6', 'ALPES-MARITIMES', 'CANNES', '122', '', 'BD DE LA REPUBLIQUE', '3', '1', '2', '1001', '', 'DH', '178', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# BD DE LA REPUBLIQUE
# ['', '', '060290241515G', '', '6', 'ALPES-MARITIMES', 'CANNES', '122', '', 'BD DE LA REPUBLIQUE', '6', '1', '2', '2001', '', 'DH', '178', 'AP', 'Partie principale', '', '6', '74', '', '', '', '', '', '', '', '', '', '', '', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2021', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# BD DE LA REPUBLIQUE
# ['', '', '060290241495R', '', '6', 'ALPES-MARITIMES', 'CANNES', '122', '', 'BD DE LA REPUBLIQUE', '4', '1', '0', '2001', '', 'DH', '178', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', 'N', 'N', '', '', '3', '2', '', '', '', '', '', '', '', '', '130017379', 'DRFIP MAYOTTE', '7171', '01/01/2022', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# BD DE LA REPUBLIQUE
# ['', '', '060290241510D', '', '6', 'ALPES-MARITIMES', 'CANNES', '122', '', 'BD DE LA REPUBLIQUE', '6', '1', '0', '1001', '', 'DH', '178', 'AP', 'Partie principale', '', '5', '64', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# SUEIL
# AV SAINTE MARGUERITE
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# RUE EMILE LEONARD
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# LES VERGNADES
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# AV CHARLES DE GAULLE
# BD CHANZY
# ['', '', '084090111640C', '', '8', 'ARDENNES', 'SEDAN', '42', '', 'BD CHANZY', '12', '1', '1', '12300', '', 'BH', '54', 'AP', 'Partie principale', '', '8', '114', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# BD CHANZY
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING
# RUE D'ESSLING

# %% [markdown]
# # Écriture des lignes restantes dans les fichiers de reste correspondant

# %%
# Écrire les lignes GMBI non traitées dans le nouveau fichier
# Parcourir les lignes du fichier GMBI
for ligne_GMBI in donnees_fichierGMBI:
    # Vérifier si le numéro de logement de la ligne GMBI n'a pas été traité
    if ligne_GMBI[2] not in valeurs_gmbi_traitees:
        # Appeler la fonction pour écrire la ligne dans le fichier GMBI_non_trouve
        ecrire_ligne_csv(GMBI_non_trouve, ligne_GMBI)
        # ecrire_ligne_csv(nouveau_fichier, ligne_GMBI)

# Écrire les lignes G2GAI non traitées dans le fichier de sortie
# Parcourir les lignes du fichier G2GAI
for ligne_G2GAI in donnees_fichierG2GAI:
    # Vérifier si le numéro de logement de la ligne G2GAI n'a pas été traité
    if ligne_G2GAI[12] not in valeurs_g2gai_traitees:
        # Appeler la fonction pour écrire la ligne dans le fichier G2GAI_non_trouve
        ecrire_ligne_csv(G2GAI_non_trouve, ligne_G2GAI)

# Écrire les lignes PARTIE non traitées dans le fichier de sortie
# Parcourir les lignes du fichier G2GAI
for ligne_abandon in donnees_fichierAbandon: 
    # Vérifier si le numéro de logement de la ligne G2GAI n'a pas été traité
    if ligne_abandon[0] not in valeurs_abandon_traitees:
        # Appeler la fonction pour écrire la ligne dans le fichier G2GAI_non_trouve
        ecrire_ligne_csv(nom_abandon_non_trouve, ligne_abandon)

# %% [markdown]
# # Affichage du temps d'exécution du programme

# %%
# Temps exécution programme
end = time.time()
execution_time = end - start
hours, remainder = divmod(execution_time, 3600)
minutes, seconds = divmod(remainder, 60)
print("Temps d'exécution total : {:0>2}:{:0>2}:{:05.2f}".format(int(hours), int(minutes), seconds))
# Out:
# Temps d'exécution total : 00:26:21.91

# %% [markdown]
# # Ouvrir les fichiers de rendu

# %%
# Ouvre le fichier CSV avec l'application par défaut
os.startfile(nouveau_fichier)
os.startfile(G2GAI_non_trouve)
os.startfile(GMBI_non_trouve)
